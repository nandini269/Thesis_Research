# %%
import numpy as np
import pandas as pd
import os

# %%
data_path = '/data/cy438/selected_datasets/'

# %%
pd.read_csv(os.path.join(data_path, 'dataset_3_features_and_labels.csv'), index_col=None, header=None)
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 1    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 2    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 3    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 4    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 5    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 6    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 7    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 8    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 9    -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# 10   -0.354610  0.354610 -0.275195  0.275195 -0.197514  0.197514 -0.334722
# ...
